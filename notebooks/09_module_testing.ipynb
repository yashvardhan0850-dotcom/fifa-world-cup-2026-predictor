# %%
import sys
import os

# %%
sys.path.append(
    os.path.abspath('..')
)

# %%
from src.team_strength import *

# %%
team_profiles_df = build_team_profiles()

# %%
team_profiles_df.head(20)
# Out:
#             team  matches_played  wins  draws  losses   win_pct  \
# 77        France             111    71     22      18  0.639640
# 82         Spain             107    65     30      12  0.607477
# 150      Belgium             105    66     19      20  0.628571
# 90     Argentina             106    72     19      15  0.679245
# 91         Japan             112    71     16      25  0.633929
# 94       England             110    69     20      21  0.627273
# 104       Brazil             104    64     22      18  0.615385
# 101     Portugal             105    63     23      19  0.600000
# 93   Netherlands             100    56     24      20  0.560000
# 110      Morocco             119    78     26      15  0.655462
# 40       Algeria             113    72     25      16  0.637168
# 89         Italy              97    57     23      17  0.587629
# 22          Iran              94    61     15      18  0.648936
# 81       Germany             102    52     24      26  0.509804
# ...

# %%
save_team_profiles()
# Out:
# ✅ team_strength_profiles.csv saved successfully
#               team  matches_played  wins  draws  losses   win_pct  \
# 77          France             111    71     22      18  0.639640
# 82           Spain             107    65     30      12  0.607477
# 150        Belgium             105    66     19      20  0.628571
# 90       Argentina             106    72     19      15  0.679245
# 91           Japan             112    71     16      25  0.633929
# ..             ...             ...   ...    ...     ...       ...
# 157         Bhutan              28     4      2      22  0.142857
# 25   Liechtenstein              79     5     10      64  0.063291
# 160     Seychelles              50     2     13      35  0.040000
# 197       Anguilla              40     4      6      30  0.100000
# 216     San Marino              78     2      7      69  0.025641
#
#      avg_goals_scored  avg_goals_conceded  avg_opponent_elo  elite_wins  \
# ...
